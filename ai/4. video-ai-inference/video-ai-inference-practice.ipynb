# %%
import os
import yt_dlp
import cv2
from ultralytics import YOLO
#from moviepy.editor import ImageSequenceClip

# %% [markdown]
# ### 1. Yutube 영상 다운로드

# %%
# 다운로드할 YouTube URL
url = "https://www.youtube.com/shorts/DsXmREropi0"

# yt-dlp 설정
ydl_opts = {
    "format": "best",
    "outtmpl": "downloaded_video.%(ext)s",
}

# 다운로드
with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    ydl.download([url])
# Out:
# [youtube] Extracting URL: https://www.youtube.com/shorts/DsXmREropi0
# [youtube] DsXmREropi0: Downloading webpage
# [youtube] DsXmREropi0: Downloading ios player API JSON
# [youtube] DsXmREropi0: Downloading mweb player API JSON
# [youtube] DsXmREropi0: Downloading player 89dfc5b3
# [youtube] DsXmREropi0: Downloading m3u8 information
# [info] DsXmREropi0: Downloading 1 format(s): 18
# [download] Destination: downloaded_video.mp4
# [download] 100% of    3.56MiB in 00:00:00 at 18.90MiB/s

# %% [markdown]
# ### 2. 동영상의 fps 정보

# %%
# 동영상 파일 경로
video_path = "downloaded_video.mp4"

# 동영상 파일 열기
cap = cv2.VideoCapture(video_path)

# FPS 가져오기
fps = cap.get(cv2.CAP_PROP_FPS)
print("FPS:", fps)

# 동영상 파일 닫기
cap.release()
# Out:
# FPS: 25.0

# %% [markdown]
# ### 3. 동영상을 프레임 단위로 분할

# %%
video_path = "downloaded_video.mp4"

# cv2를 이용해 동영상 파일 열기
cap = cv2.VideoCapture(video_path)

# 프레임을 저장할 디렉토리 생성
output_dir = "frames"
os.makedirs(output_dir, exist_ok=True)

# 프레임 단위로 이미지로 저장
frame_count = 0
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    # 이미지 파일로 프레임 저장
    frame_path = os.path.join(output_dir, f"frame_{frame_count:04d}.jpg")
    cv2.imwrite(frame_path, frame)
    frame_count += 1

# 동영상 파일 닫기
cap.release()
print(f"총 {frame_count}개의 프레임이 저장되었습니다.")
# Out:
# 총 1242개의 프레임이 저장되었습니다.

# %% [markdown]
# ### 4. YOLOv8 추론

# %%
# Load a model
model = YOLO("yolov8n.pt")  # pretrained YOLO8n model

# "frames" 디렉토리 안에 있는 파일과 폴더 목록을 가져옴
frames = os.listdir("frames/")

# 원하는 디렉토리 경로 설정
directory_path = "results2"

# 디렉토리가 없으면 생성
if not os.path.exists(directory_path):
    os.makedirs(directory_path)
    print(f"디렉토리 '{directory_path}'가 생성되었어.")
else:
    print(f"디렉토리 '{directory_path}'가 이미 존재해.")

for frame in frames:
    # YOLOv8 모델을 사용하여 객체 감지 수행
    results = model("frames/" + frame,names=[0])  # , device="mps" (맥북)

    # Process results list
    for result in results:
        result.save(filename="results/" + frame)  # save to disk
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 45.3MB/s]
# 디렉토리 'results'가 생성되었어.
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0416.jpg: 640x384 3 persons, 372.5ms
# Speed: 36.6ms preprocess, 372.5ms inference, 19.3ms postprocess per image at shape (1, 3, 640, 384)
# [W1127 17:15:31.265342567 NNPACK.cpp:61] Could not initialize NNPACK! Reason: Unsupported hardware.
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0497.jpg: 640x384 2 persons, 1 sports ball, 234.2ms
# Speed: 1.2ms preprocess, 234.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_
5ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0795.jpg: 640x384 3 persons, 193.8ms
# Speed: 1.4ms preprocess, 193.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0739.jpg: 640x384 1 person, 203.2ms
# Speed: 2.9ms preprocess, 203.2ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_1230.jpg: 640x384 3 persons, 301.3ms
# Speed: 3.6ms preprocess, 301.3ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0253.jpg: 640x384 1 person, 258.7ms
# Speed: 1.2ms preprocess, 258.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0451.jpg: 640x384 4 persons, 1 sports ball, 195.3ms
# Speed: 12.7ms preprocess, 195.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0258.jpg: 640x384 10 persons, 1 sports ball, 314.9ms
# Speed: 3.0ms preprocess, 314.9ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_1020.jpg: 640x384 3 persons, 311.0ms
# Speed: 7.5ms preprocess, 311.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_1164.jpg: 640x384 3 persons, 358.3ms
# Speed: 5.0ms preprocess, 358.3ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0216.jpg: 640x384 1 person, 1 sports ball, 164.5ms
# Speed: 7.0ms preprocess, 164.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0753.jpg: 640x384 3 persons, 1 car, 258.3ms
# Speed: 1.4ms preprocess, 258.3ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0374.jpg: 640x384 2 persons, 1 sports ball, 290.3ms
# Speed: 6.7ms preprocess, 290.3ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0225.jpg: 640x384 1 person, 1 sports ball, 230.4ms
# Speed: 2.3ms preprocess, 230.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# ...
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_1176.jpg: 640x384 3 persons, 141.9ms
# Speed: 1.4ms preprocess, 141.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0752.jpg: 640x384 2 persons, 1 car, 130.6ms
# Speed: 1.4ms preprocess, 130.6ms inference, 4.7ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0226.jpg: 640x384 1 person, 2 sports balls, 141.7ms
# Speed: 1.3ms preprocess, 141.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0388.jpg: 640x384 1 person, 1 sports ball, 180.1ms
# Speed: 1.7ms preprocess, 180.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_1013.jpg: 640x384 5 persons, 130.9ms
# Speed: 1.7ms preprocess, 130.9ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0529.jpg: 640x384 1 person, 2 sports balls, 255.2ms
# Speed: 13.6ms preprocess, 255.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_1214.jpg: 640x384 2 persons, 111.1ms
# Speed: 1.4ms preprocess, 111.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_1069.jpg: 640x384 5 persons, 133.8ms
# Speed: 1.3ms preprocess, 133.8ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0143.jpg: 640x384 2 persons, 156.8ms
# Speed: 2.1ms preprocess, 156.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0398.jpg: 640x384 (no detections), 146.1ms
# Speed: 1.3ms preprocess, 146.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0290.jpg: 640x384 8 persons, 123.5ms
# Speed: 1.7ms preprocess, 123.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0797.jpg: 640x384 2 persons, 133.1ms
# Speed: 1.6ms preprocess, 133.1ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_1179.jpg: 640x384 3 persons, 153.8ms
# Speed: 2.7ms preprocess, 153.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0073.jpg: 640x384 4 persons, 1 sports ball, 139.5ms
# Speed: 1.2ms preprocess, 139.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_1063.jpg: 640x384 5 persons, 160.0ms
# Speed: 1.6ms preprocess, 160.0ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_1094.jpg: 640x384 5 persons, 192.6ms
# Speed: 12.2ms preprocess, 192.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_1191.jpg: 640x384 3 persons, 327.0ms
# Speed: 1.1ms preprocess, 327.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0708.jpg: 640x384 5 persons, 252.0ms
# Speed: 1.2ms preprocess, 252.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0161.jpg: 640x384 1 person, 1 sports ball, 161.1ms
# Speed: 1.8ms preprocess, 161.1ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0445.jpg: 640x384 3 persons, 158.6ms
# Speed: 3.5ms preprocess, 158.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0962.jpg: 640x384 1 person, 166.9ms
# Speed: 1.1ms preprocess, 166.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_1139.jpg: 640x384 3 persons, 238.1ms
# Speed: 1.5ms preprocess, 238.1ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0598.jpg: 640x384 3 persons, 192.9ms
# Speed: 2.4ms preprocess, 192.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0506.jpg: 640x384 2 persons, 1 sports ball, 195.0ms
# Speed: 1.6ms preprocess, 195.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0364.jpg: 640x384 4 persons, 162.1ms
# Speed: 1.3ms preprocess, 162.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0692.jpg: 640x384 6 persons, 109.2ms
# Speed: 4.0ms preprocess, 109.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0533.jpg: 640x384 1 person, 1 sports ball, 89.4ms
# Speed: 1.3ms preprocess, 89.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0833.jpg: 640x384 2 persons, 1 baseball bat, 1 baseball glove, 135.8ms
# Speed: 4.1ms preprocess, 135.8ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0686.jpg: 640x384 6 persons, 157.2ms
# Speed: 1.9ms preprocess, 157.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_1078.jpg: 640x384 6 persons, 96.4ms
# Speed: 11.6ms preprocess, 96.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_1072.jpg: 640x384 5 persons, 122.4ms
# Speed: 1.6ms preprocess, 122.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0835.jpg: 640x384 2 persons, 1 baseball glove, 194.6ms
# Speed: 1.6ms preprocess, 194.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0233.jpg: 640x384 1 person, 1 sports ball, 183.6ms
# Speed: 7.8ms preprocess, 183.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_1181.jpg: 640x384 3 persons, 151.3ms
# Speed: 1.6ms preprocess, 151.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0841.jpg: 640x384 1 person, 192.0ms
# Speed: 2.3ms preprocess, 192.0ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0677.jpg: 640x384 6 persons, 154.3ms
# Speed: 4.0ms preprocess, 154.3ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0574.jpg: 640x384 (no detections), 116.3ms
# Speed: 1.6ms preprocess, 116.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0204.jpg: 640x384 1 person, 101.7ms
# Speed: 1.2ms preprocess, 101.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0524.jpg: 640x384 2 persons, 2 sports balls, 124.0ms
# Speed: 1.9ms preprocess, 124.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_1226.jpg: 640x384 2 persons, 105.3ms
# Speed: 1.4ms preprocess, 105.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0172.jpg: 640x384 3 persons, 1 sports ball, 82.4ms
# Speed: 2.3ms preprocess, 82.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_1095.jpg: 640x384 6 persons, 122.4ms
# Speed: 1.1ms preprocess, 122.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_1133.jpg: 640x384 3 persons, 143.6ms
# Speed: 2.1ms preprocess, 143.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0548.jpg: 640x384 1 person, 252.2ms
# Speed: 1.9ms preprocess, 252.2ms inference, 9.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0303.jpg: 640x384 6 persons, 184.9ms
# Speed: 1.3ms preprocess, 184.9ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0709.jpg: 640x384 4 persons, 197.8ms
# Speed: 1.2ms preprocess, 197.8ms inference, 4.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0759.jpg: 640x384 2 persons, 1 motorcycle, 126.1ms
# Speed: 1.6ms preprocess, 126.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0964.jpg: 640x384 1 person, 101.5ms
# Speed: 1.2ms preprocess, 101.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0013.jpg: 640x384 7 persons, 1 sports ball, 125.9ms
# Speed: 1.2ms preprocess, 125.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0966.jpg: 640x384 1 person, 161.7ms
# Speed: 1.0ms preprocess, 161.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0048.jpg: 640x384 10 persons, 107.2ms
# Speed: 1.3ms preprocess, 107.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0184.jpg: 640x384 2 persons, 87.2ms
# Speed: 1.5ms preprocess, 87.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0626.jpg: 640x384 6 persons, 1 kite, 86.8ms
# Speed: 1.3ms preprocess, 86.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0756.jpg: 640x384 3 persons, 151.3ms
# Speed: 5.5ms preprocess, 151.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0380.jpg: 640x384 3 persons, 2 sports balls, 166.4ms
# Speed: 1.7ms preprocess, 166.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0541.jpg: 640x384 3 persons, 325.3ms
# Speed: 2.4ms preprocess, 325.3ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0319.jpg: 640x384 4 persons, 198.9ms
# Speed: 10.0ms preprocess, 198.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_1066.jpg: 640x384 5 persons, 160.2ms
# Speed: 13.5ms preprocess, 160.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0975.jpg: 640x384 1 person, 136.8ms
# Speed: 2.1ms preprocess, 136.8ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0126.jpg: 640x384 2 persons, 185.7ms
# Speed: 12.5ms preprocess, 185.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0450.jpg: 640x384 5 persons, 1 sports ball, 140.9ms
# Speed: 1.9ms preprocess, 140.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0940.jpg: 640x384 4 persons, 153.2ms
# Speed: 6.6ms preprocess, 153.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0234.jpg: 640x384 1 person, 1 sports ball, 125.3ms
# Speed: 1.3ms preprocess, 125.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0881.jpg: 640x384 2 persons, 95.1ms
# Speed: 2.5ms preprocess, 95.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_1182.jpg: 640x384 3 persons, 81.8ms
# Speed: 1.3ms preprocess, 81.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0439.jpg: 640x384 2 persons, 77.5ms
# Speed: 1.3ms preprocess, 77.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0687.jpg: 640x384 6 persons, 88.4ms
# Speed: 1.2ms preprocess, 88.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0480.jpg: 640x384 (no detections), 116.2ms
# Speed: 1.3ms preprocess, 116.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_0783.jpg: 640x384 2 persons, 187.6ms
# Speed: 5.1ms preprocess, 187.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_1187.jpg: 640x384 3 persons, 239.3ms
# Speed: 2.1ms preprocess, 239.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /home/aaa/vision-ai-inference-practice/4. video-ai-inference/frames/frame_1156.jpg: 640x384 3 persons, 166.3ms
# Speed: 2.6ms preprocess, 166.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)

# %% [markdown]
# ### 5. 프레임을 동영상으로 변환 - moviepy 라이브러리

# %%
# 이미지 파일들이 저장된 디렉토리 경로
image_folder = "results"  # 이미지 파일들이 있는 폴더 경로
fps = int(fps)  # 초당 프레임 수 설정

# 이미지 파일 리스트 가져오기 (예: jpg, png 형식)
image_files = [
    os.path.join(image_folder, img)
    for img in sorted(os.listdir(image_folder))
    if img.endswith((".jpg", ".png"))
]

# 이미지 시퀀스를 이용해 클립 생성
clip = ImageSequenceClip(image_files, fps=fps)

# 동영상 파일로 저장
output_path = "output_video.mp4"
clip.write_videofile(output_path, codec="libx264")

print(f"동영상이 생성되었습니다: {output_path}")

# %%
image_folder = 'results'  # 이미지들이 저장된 폴더 경로
video_name = 'output_video.mp4'  # 저장할 비디오 파일 이름

# 이미지 파일 이름을 읽고 정렬 (순서대로 동영상을 만들기 위해)
images = [img for img in os.listdir(image_folder) if img.endswith(".png") or img.endswith(".jpg")]
images.sort()

# 첫 번째 이미지에서 프레임의 너비와 높이 가져오기
frame = cv2.imread(os.path.join(image_folder, images[0]))
height, width, layers = frame.shape

# 비디오 코덱과 파일명 설정, FPS 설정
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # mp4 코덱 설정
video = cv2.VideoWriter(video_name, fourcc, 30, (width, height))  # FPS를 30으로 설정

# 이미지를 순차적으로 불러와서 비디오에 추가
for image in images:
    frame = cv2.imread(os.path.join(image_folder, image))
    video.write(frame)

# 비디오 파일 저장 종료
video.release()
cv2.destroyAllWindows()
